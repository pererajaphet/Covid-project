# %%
# !pip install mysql.connector

# %%
import mysql.connector

# %%
# ici ma database cest "final_data_sql" et ma table cest "test"

mydb = mysql.connector.connect(host="localhost",
                              user="root",
                              passwd="",
                              database="final_data_sql")
mycursor = mydb.cursor()

# %%
mycursor.execute("select rmse from test")

for x in mycursor:
    print(x)
# Out:
# (0.045852661,)
# (0.001770617,)
# (0.033656985,)
# (0.007785665,)
# (0.03017102,)
# (0.070594445,)
# (0.059003852,)
# (0.026975576,)
# (0.090256184,)
# (0.02582543,)
# (0.077937983,)
# (0.065813228,)
# (0.027681923,)
# (0.045958377,)
# (0.027777113,)
# (0.0047672,)
# (0.023960546,)
# (0.062716424,)
# (0.065670423,)
# (0.028128421,)
# (0.032608017,)
# (0.039313007,)
# (0.124863856,)
# (0.002552317,)
# (0.10044121,)
# (0.166365236,)
# (0.007716475,)
# (0.04348895,)
# (0.003103614,)
# (0.142870933,)
# (0.079978637,)
# (0.014230295,)
# (0.187262475,)
# (0.056437451,)
# (0.032380503,)
# (0.022513296,)
# (0.039109398,)
# (0.020245846,)
# (0.147329643,)
# (0.028426996,)
# (0.017533304,)
# (0.005539697,)
# (0.038308717,)
# (0.085317746,)
# (0.020425387,)
# (0.029970789,)
# (0.014779585,)
# (0.023375688,)
# (0.17200163,)
# (0.097005367,)
# (0.04842104,)
# (0.023503926,)
# (0.015563735,)
# (0.006055393,)
# (0.030012555,)
# (0.137975827,)
# (0.003779522,)
# (0.118060872,)
# (0.040609844,)
# ...
